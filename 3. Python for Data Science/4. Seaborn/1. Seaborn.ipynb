# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_crashes = sns.load_dataset('car_crashes')
df_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df_tips = sns.load_dataset('tips')
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_flights = sns.load_dataset('flights')
df_flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_iris = sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_titanic = sns.load_dataset('titanic')
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.relplot(x='sepal_width', y='sepal_length', data=df_iris, kind='line')

# %%
sns.relplot(x='sepal_width', y='sepal_length', data=df_iris)

# %%
plt.plot(df_iris['sepal_width'], df_iris['sepal_length'])

# %%
sns.relplot(x='sepal_width', y='sepal_length', data=df_iris, kind='line', hue='species')

# %%
sns.relplot(x='sepal_width', y='sepal_length', data=df_iris, kind='line', hue='species', style='species')

# %%
sns.relplot(x=df_iris.sepal_width, y=df_iris.sepal_length, kind='line', hue=df_iris.species)

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=df_tips, hue='sex', style='day',)

# %%
sns.relplot(x='total_bill', y='tip', data=df_tips, col='day', col_wrap=2)

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex', y='survived', data=df_titanic, kind='bar')

# %%
sns.catplot(x='sex', data=df_titanic, kind='count')

# %%
sns.catplot(y='sex', data=df_titanic, kind='count')

# %%
sns.catplot(x='sex', kind='count', data=df_titanic, hue='survived')

# %%
sns.catplot(x='sex', y='age', kind='box', data=df_titanic)

# %%
sns.catplot(x='sex', y='age', kind='box', hue='survived', data=df_titanic)

# %%
sns.catplot(x='sex', y='age', kind='violin', data=df_titanic)

# %%
sns.catplot(x='sex', y='age', kind='violin', data=df_titanic, hue='survived')

# %%
sns.catplot(y='age', kind='strip', data=df_titanic)

# %%
sns.catplot(y='age', x='survived', kind='strip', hue='sex', data=df_titanic)

# %%
sns.catplot(x='sex', y='age', kind='swarm', hue='survived', data=df_titanic)

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(x='total_bill', kind='hist', data=df_tips)

# %%
sns.displot(x='total_bill', kind='hist', bins=30, data=df_tips)

# %%
sns.displot(y='total_bill', kind='hist', data=df_tips)

# %%
sns.displot(y='total_bill', kind='kde', data=df_tips)
